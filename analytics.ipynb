# %%
import sys
import pandas as pd
import os

# %%
df = pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\BigData1\data_preprocessed.csv')
df
# Out:
#              PC1       PC2       PC3       PC4       PC5 PC1_bin
# 0       0.153594 -0.995444 -1.525382 -9.131426 -0.344289  Medium
# 1       1.652804 -0.999780 -1.527168 -8.723363 -0.551109  Medium
# 2      -0.480285 -1.995077 -1.517635 -8.441010  0.392676  Medium
# 3       3.191915  3.003294 -0.577003 -8.200134  0.289549    High
# 4       2.729051  1.995538 -1.553551 -8.021890 -0.662452    High
# ...          ...       ...       ...       ...       ...     ...
# 49995   1.839235 -0.005694  0.418063  1.002621 -0.061141    High
# 49996  -1.974166  2.986509 -1.574514  0.999883 -0.016929     Low
# 49997   4.481410  0.971413 -1.560497  1.009411 -0.090076    High
# 49998  11.871040  0.953269 -1.563274  1.018363  0.184391    High
# 49999   3.312457  1.000731  1.568250  1.009901  0.060944    High
#
# [50000 rows x 6 columns]

# %%
with open("insight1.txt","w") as f:
    f.write(f"Most users fall into engagement group: {df['PC1'].value_counts().idxmax()}")

# %%
with open("insight2.txt","w") as f:
    f.write(f"Average PC1 (engagement proxy): {df['PC1'].mean():.2f}")

# %%
with open("insight3.txt","w") as f:
    f.write(f"Variance in behavior (PC2 std): {df['PC2'].std():.2f}")

# %%
print("Analytics complete")
os.system(f"python visualize.py {df}")
# Out:
# Analytics complete
# 2
